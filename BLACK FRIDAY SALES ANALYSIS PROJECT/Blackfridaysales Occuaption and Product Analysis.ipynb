# %%
import os
import pandas as pd
import numpy as nm
import seaborn as sns
import matplotlib as plt
df= pd.read_csv(r"D:\PROJECTS\DATASETS\PYTHON\BlackFriday.csv")
del df['Product_Category_2']
del df ['Product_Category_3']

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
sns.countplot(x=df['Stay_In_Current_City_Years'])
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
df.groupby('Stay_In_Current_City_Years').size()
# Out:
# Stay_In_Current_City_Years
# 0      72725
# 1     189192
# 2      99459
# 3      93312
# 4+     82889
# dtype: int64

# %%
df.groupby('Stay_In_Current_City_Years').size().plot(kind= 'pie', autopct="%.1f", figsize=(6,6), title= 'Stay in current city years')
# Out:
# <Axes: title={'center': 'Stay in current city years'}>

# %%
sns.countplot(x='Stay_In_Current_City_Years', hue='Gender', data=df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x='Stay_In_Current_City_Years', hue='Marital_Status', data = df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x ='Stay_In_Current_City_Years', hue='City_Category', data =df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x='City_Category', hue='Stay_In_Current_City_Years', data=df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(x='City_Category', hue='Age', data=df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
df.groupby('Stay_In_Current_City_Years').sum()['Purchase'].plot(kind='bar', figsize=(12,6))
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years'>

# %%
df.groupby('Stay_In_Current_City_Years').mean(numeric_only=True)['Purchase'].plot(kind = 'bar')
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years'>

# %%
df['Occupation'].unique()
# Out:
# array([10, 16, 15,  7, 20,  9,  1, 12, 17,  0,  3,  4, 11,  8, 19,  2, 18,
#         5, 14, 13,  6], dtype=int64)

# %%
sns.countplot(x=df['Occupation'])
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby('Occupation').size().sort_values().plot(kind='bar',figsize=(6,6), title='Occupation') #".sort_values" sorts the values asc.
# Out:
# <Axes: title={'center': 'Occupation'}, xlabel='Occupation'>

# %%
df.groupby('Occupation').sum()['Purchase'].sort_values().plot(kind='bar', figsize=(6,6), title='Sum of Purchase vs Occupation')
# Out:
# <Axes: title={'center': 'Sum of Purchase vs Occupation'}, xlabel='Occupation'>

# %%
df.groupby('Occupation').mean(numeric_only=True)['Purchase'].sort_values().plot(kind='bar',figsize=(6,6), title='Mean Purchase vs Occupation')
# Out:
# <Axes: title={'center': 'Mean Purchase vs Occupation'}, xlabel='Occupation'>

# %%
sns.countplot(x='Occupation', hue='Marital_Status',data = df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
sns.countplot(x='Occupation', hue='Gender', data =df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby('Occupation').nunique()['Purchase'].plot(kind='bar', figsize=(6,6), title='Unique Products bought by specifc occupation')
# Out:
# <Axes: title={'center': 'Unique Products bought by specifc occupation'}, xlabel='Occupation'>

# %%
df.groupby('Occupation')['Purchase'].nunique().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Product_Category_1').size().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby('Product_Category_1').size().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby('Product_Category_1')['Purchase'].sum().sort_values().plot(kind='bar', title='Sum Purchase by Product Category')
# Out:
# <Axes: title={'center': 'Sum Purchase by Product Category'}, xlabel='Product_Category_1'>

# %%
df.groupby('Product_Category_1')['Purchase'].mean(numeric_only=True).sort_values().plot(kind='bar', title='Mean Purchase by Product Category')
# Out:
# <Axes: title={'center': 'Mean Purchase by Product Category'}, xlabel='Product_Category_1'>

# %%
sns.countplot(x='Product_Category_1', hue='Gender', data =df)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
sns.countplot(x='Product_Category_1', hue='City_Category', data = df)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
sns.countplot(x='Product_Category_1', hue='Marital_Status', data =df)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
df.groupby('Product_ID')['Purchase'].sum().nlargest(10).plot(kind='bar') # ".nlargest()"---top n largest values.
# Out:
# <Axes: xlabel='Product_ID'>

# %%
df.groupby('Product_ID')['Purchase'].sum().nlargest(10).sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %%
df.groupby('Product_ID').size().nlargest(10).sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>
