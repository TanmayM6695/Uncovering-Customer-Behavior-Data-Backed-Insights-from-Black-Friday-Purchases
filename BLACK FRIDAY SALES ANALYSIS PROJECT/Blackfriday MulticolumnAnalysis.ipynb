# %%
import os
import pandas as pd
import seaborn as sns
df = pd.read_csv(r"D:\PROJECTS\DATASETS\PYTHON\BlackFriday.csv")
del df['Product_Category_2']
del df ['Product_Category_3']

# %%
df.head(10)
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000001  P00069042      F   0-17          10             A
# 1  1000001  P00248942      F   0-17          10             A
# 2  1000001  P00087842      F   0-17          10             A
# 3  1000001  P00085442      F   0-17          10             A
# 4  1000002  P00285442      M    55+          16             C
# 5  1000003  P00193542      M  26-35          15             A
# 6  1000004  P00184942      M  46-50           7             B
# 7  1000004  P00346142      M  46-50           7             B
# 8  1000004   P0097242      M  46-50           7             B
# 9  1000005  P00274942      M  26-35          20             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# ...

# %%
df.groupby('Age').size().plot(kind='bar',figsize=(12,6), title='Purchase Distyribution by Age')
# Out:
# <Axes: title={'center': 'Purchase Distyribution by Age'}, xlabel='Age'>

# %%
sns.set(rc = {'figure.figsize' : (12,6)})
sns.countplot(x = "Age", hue = 'Gender', data = df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.set(rc = {'figure.figsize' : (12,6)})
sns.countplot(x = "Gender", hue = 'Age', data = df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.set(rc = {'figure.figsize' : (6,6)})
sns.countplot(x = "Gender", hue = 'Marital_Status', data = df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.set(rc = {'figure.figsize' : (6,6)})
sns.countplot(x = "Marital_Status", hue = 'Gender', data = df)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
df['City_Category'].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
sns.countplot(x=df['City_Category'])
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(x=df['City_Category'], hue='Gender',data =df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
female_counts_by_city = df[df['Gender'] == 'F']['City_Category'].value_counts()
print(female_counts_by_city)
# Out:
# City_Category
# B    56494
# C    40896
# A    34807
# Name: count, dtype: int64

# %%
sns.countplot(x = 'City_Category', hue = 'Age', data = df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(x = 'Age', hue = 'City_Category', data = df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x = 'Marital_Status', hue = 'City_Category', data = df)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
df.groupby('City_Category').size().plot(kind = 'pie', autopct = '%0.1f',figsize=(4,4), colors=['pink','skyblue','violet'])
# Out:
# <Axes: >

# %%
df.groupby('City_Category').sum()['Purchase'].plot(kind = 'pie', autopct = "%0.1f",figsize=(4,4))
# Out:
# <Axes: ylabel='Purchase'>

# %%
import os
import pandas as pd
import seaborn as sns
df = pd.read_csv(r"D:\PROJECTS\DATASETS\PYTHON\BlackFriday.csv")
del df['Product_Category_2']
del df ['Product_Category_3']

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969
